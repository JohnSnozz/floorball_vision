# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data=fb_training_images/data.yaml epochs=200 imgsz=1080 batch=4
# Out:
# Ultralytics 8.3.127 🚀 Python-3.13.3 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4060 Ti, 16380MiB)
# ...
